# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train=pd.read_csv('/content/train.csv')
train.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
test=pd.read_csv('/content/test.csv')
test.head(4)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
# 3          895       3                  Wirz, Mr. Albert    male  27.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q
# 3      0  315154  8.6625   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test.duplicated().sum()
# Out:
# 0

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
train['Cabin']=train['Cabin'].fillna('x')

# %%
train['Cabin']=train['Cabin'].str.split('').apply(lambda x: x[1])

# %%
train['Cabin'].value_counts()
# Out:
# x    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Cabin, dtype: int64

# %%
sns.countplot(data=train,x='Cabin',hue='Survived')
# Out:
# <Axes: xlabel='Cabin', ylabel='count'>

# %%
sns.barplot(data=train,x='Cabin',y='Fare',hue='Survived')
# Out:
# <Axes: xlabel='Cabin', ylabel='Fare'>

# %%
test['Cabin']=test['Cabin'].fillna('x')
test['Cabin']=train['Cabin'].str.split('').apply(lambda x: x[1])

# %%
train.groupby('Cabin')['Fare'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Cabin'>

# %%
train.groupby('Cabin')['Fare'].mean()
# Out:
# Cabin
# A     39.623887
# B    113.505764
# C    100.151341
# D     57.244576
# E     46.026694
# F     18.696792
# G     13.581250
# T     35.500000
# x     19.157325
# Name: Fare, dtype: float64

# %%
sns.histplot(data=train,x='Fare',kde=True,hue='Survived')
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
train.groupby('Cabin')['Survived'].value_counts()
# Out:
# Cabin  Survived
# A      0             8
#        1             7
# B      1            35
#        0            12
# C      1            35
#        0            24
# D      1            25
#        0             8
# E      1            24
#        0             8
# F      1             8
#        0             5
# G      0             2
#        1             2
# T      0             1
# x      0           481
#        1           206
# Name: Survived, dtype: int64

# %%
corr=train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <ipython-input-83-4b958c326f1d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=train.corr()
# <Axes: >

# %%
def fare(r):
    if r > 45:
        return 'rich p'
    else:
        return 'poor p'

train['Fare']=train['Fare'].apply(fare)
test['Fare']=test['Fare'].apply(fare)

# %%
train.groupby('Fare')['Survived'].value_counts()
# Out:
# Fare    Survived
# poor p  0           489
#         1           231
# rich p  1           111
#         0            60
# Name: Survived, dtype: int64

# %%
def Cabin(x):
    if x =='B' or x =='C' or x=='D':

        return 'high class'
    else:
        return 'low'

train['Cabin']=train['Cabin'].apply(Cabin)
test['Cabin']=test['Cabin'].apply(Cabin)

# %%
train['Cabin'].value_counts()
# Out:
# low           752
# high class    139
# Name: Cabin, dtype: int64

# %%
sns.countplot(data=train,x='Cabin',hue='Survived')
# Out:
# <Axes: xlabel='Cabin', ylabel='count'>

# %%
#train.drop(columns='Cabin',inplace=True)
#test.drop(columns='Cabin',inplace=True)

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Embarked'].fillna('S',inplace=True)

# %%
test['Fare'].fillna(14,inplace=True)

# %%
train['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
train['title']=train['Name'].str.split(' ').apply(lambda x:x[1])

# %%
test['title']=test['Name'].str.split(' ').apply(lambda x:x[1])

# %%
def count(value):
    if value=='Mr.':
        return 'mr'
    elif value =='Miss.':
        return 'miss'
    elif value=='Mrs.':
        return 'mrs'
    else:
        return 'bade log'
train['title']= train['title'].apply(count)
test['title']=test['title'].apply(count)

# %%
train['title'].value_counts()
test['title'].value_counts()
# Out:
# mr          234
# miss         77
# mrs          70
# bade log     37
# Name: title, dtype: int64

# %%
train.groupby('title')['Age'].mean()
# Out:
# title
# bade log    22.538659
# miss        21.846154
# mr          32.389610
# mrs         36.182692
# Name: Age, dtype: float64

# %%
test.groupby('title')['Age'].mean()
# Out:
# title
# bade log    20.965937
# miss        21.644286
# mr          32.050847
# mrs         39.050000
# Name: Age, dtype: float64

# %%
avg_age=train.groupby('title')['Age'].mean().reset_index()
avg_age
# Out:
#       title        Age
# 0  bade log  22.538659
# 1      miss  21.846154
# 2        mr  32.389610
# 3       mrs  36.182692

# %%
avg_age2=test.groupby('title')['Age'].mean().reset_index()
avg_age2
# Out:
#       title        Age
# 0  bade log  20.965937
# 1      miss  21.644286
# 2        mr  32.050847
# 3       mrs  39.050000

# %%
train=train.merge(avg_age,on='title')
train.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex  Age_x  \
# 0            1         0       3         Braund, Mr. Owen Harris  male   22.0
# 1            5         0       3        Allen, Mr. William Henry  male   35.0
# 2            6         0       3                Moran, Mr. James  male    NaN
# 3            7         0       1         McCarthy, Mr. Timothy J  male   54.0
# 4           13         0       3  Saundercock, Mr. William Henry  male   20.0
#
#    SibSp  Parch     Ticket    Fare Cabin Embarked title     Age_y
# 0      1      0  A/5 21171  poor p   low        S    mr  32.38961
# 1      0      0     373450  poor p   low        S    mr  32.38961
# 2      0      0     330877  poor p   low        Q    mr  32.38961
# 3      0      0      17463  rich p   low        S    mr  32.38961
# 4      0      0  A/5. 2151  poor p   low        S    mr  32.38961

# %%
test=test.merge(avg_age2,on='title')

# %%
test
# Out:
#      PassengerId  Pclass                           Name     Sex  Age_x  SibSp  \
# 0            892       3               Kelly, Mr. James    male   34.5      0
# 1            894       2      Myles, Mr. Thomas Francis    male   62.0      0
# 2            895       3               Wirz, Mr. Albert    male   27.0      0
# 3            897       3     Svensson, Mr. Johan Cervin    male   14.0      0
# 4            899       2   Caldwell, Mr. Albert Francis    male   26.0      1
# ..           ...     ...                            ...     ...    ...    ...
# 413         1271       3    Asplund, Master. Carl Edgar    male    5.0      4
# 414         1281       3    Palsson, Master. Paul Folke    male    6.0      3
# 415         1284       3  Abbott, Master. Eugene Joseph    male   13.0      0
# 416         1306       1   Oliva y Ocana, Dona. Fermina  female   39.0      0
# 417         1309       3       Peter, Master. Michael J    male    NaN      1
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age_x        714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    object
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
#  12  title        891 non-null    object
#  13  Age_y        891 non-null    float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 104.4+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age_x        332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    object
#  9   Cabin        418 non-null    object
#  10  Embarked     418 non-null    object
#  11  title        418 non-null    object
#  12  Age_y        418 non-null    float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 45.7+ KB

# %%
surr=train.groupby('Survived')

# %%
train.groupby('Pclass')['Survived'].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
train.groupby('Pclass')['Survived'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
train.groupby('Sex')['Survived'].mean().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='Sex'>

# %%
train.groupby('SibSp')['Survived'].mean().plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='SibSp'>

# %%
train.groupby('Parch')['Survived'].mean().plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='Parch'>

# %%
train['family']=train['Parch']+train['SibSp']+1
test['family']=test['Parch']+test['SibSp']+1

# %%
train.groupby('family')['Survived'].mean().plot(kind='bar',color='black')
# Out:
# <Axes: xlabel='family'>

# %%
def cal(num):
    if num==1:
        return 'alone'

    elif num>1 and num<5:
        return 'avg family'
    else:
        return 'bade family'

# %%
train['family']=train['family'].apply(cal)
test['family']= test['family'].apply(cal)

# %%
train.groupby('family')['Survived'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='family'>

# %%
train.groupby('Embarked')['Survived'].mean().plot(kind='bar',color='black')
# Out:
# <Axes: xlabel='Embarked'>

# %%
train['title'].value_counts()
# Out:
# mr          502
# miss        179
# mrs         121
# bade log     89
# Name: title, dtype: int64

# %%
train.groupby('title')['Survived'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='title'>

# %%
passengerid= test['PassengerId']

# %%
tr1=train
tst1=test

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age_x        714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    object
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
#  12  title        891 non-null    object
#  13  Age_y        891 non-null    float64
#  14  family       891 non-null    object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 111.4+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age_x        332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    object
#  9   Cabin        418 non-null    object
#  10  Embarked     418 non-null    object
#  11  title        418 non-null    object
#  12  Age_y        418 non-null    float64
#  13  family       418 non-null    object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 49.0+ KB

# %%
train.drop(columns=['PassengerId','Name','Age_x','SibSp','Parch','Ticket'],inplace=True)

# %%
test.drop(columns=['PassengerId','Name','Age_x','SibSp','Parch','Ticket',],inplace=True)

# %%
train
# Out:
#      Survived  Pclass     Sex Cabin Embarked     title      Age_y      family
# 0           0       3    male     x        S        mr  32.389610  avg family
# 1           0       3    male     x        S        mr  32.389610       alone
# 2           0       3    male     x        Q        mr  32.389610       alone
# 3           0       1    male     E        S        mr  32.389610       alone
# 4           0       3    male     x        S        mr  32.389610       alone
# ..        ...     ...     ...   ...      ...       ...        ...         ...
# 886         1       2  female     x        C  bade log  22.538659  avg family
# 887         0       3    male     x        S  bade log  22.538659       alone
# 888         1       3    male     x        S  bade log  22.538659  avg family
# 889         0       3    male     x        S  bade log  22.538659       alone
# 890         0       2    male     x        S  bade log  22.538659       alone
#
# [891 rows x 8 columns]

# %%
x=train.iloc[:,1:]
y=train.iloc[:,0]

# %%
y
x
# Out:
#      Pclass      Age_y  title_miss  title_mr  title_mrs  Embarked_Q  \
# 0         3  32.389610           0         1          0           0
# 1         3  32.389610           0         1          0           0
# 2         3  32.389610           0         1          0           1
# 3         1  32.389610           0         1          0           0
# 4         3  32.389610           0         1          0           0
# ..      ...        ...         ...       ...        ...         ...
# 886       2  22.538659           0         0          0           0
# 887       3  22.538659           0         0          0           0
# 888       3  22.538659           0         0          0           0
# 889       3  22.538659           0         0          0           0
# 890       2  22.538659           0         0          0           0
#
#      Embarked_S  family_avg family  family_bade family  Cabin_low  \
# 0             1                  1                   0          1
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_test
# Out:
#      Pclass      Age_y  title_miss  title_mr  title_mrs  Embarked_Q  \
# 707       3  21.846154           1         0          0           1
# 37        3  32.389610           0         1          0           0
# 615       3  36.182692           0         0          1           0
# 169       3  32.389610           0         1          0           0
# 68        2  32.389610           0         1          0           0
# ..      ...        ...         ...       ...        ...         ...
# 89        3  32.389610           0         1          0           0
# 80        3  32.389610           0         1          0           1
# 846       1  22.538659           0         0          0           0
# 870       1  22.538659           0         0          0           0
# 251       2  32.389610           0         1          0           0
#
#      Embarked_S  family_avg family  family_bade family  Cabin_low  \
# 707           0                  0                   0          1
# ...

# %%
train=pd.get_dummies(train,columns=['title','Embarked','family','Cabin','Fare'],drop_first=True)

# %%
test=pd.get_dummies(test,columns=['title','Embarked','family','Cabin','Fare'],drop_first=True)

# %%
train=pd.get_dummies(train,columns=['Sex'],drop_first=True)
test=pd.get_dummies(test,columns=['Sex'],drop_first=True)

# %%
train
# Out:
#      Survived  Pclass      Age_y  title_miss  title_mr  title_mrs  Embarked_Q  \
# 0           0       3  32.389610           0         1          0           0
# 1           0       3  32.389610           0         1          0           0
# 2           0       3  32.389610           0         1          0           1
# 3           0       1  32.389610           0         1          0           0
# 4           0       3  32.389610           0         1          0           0
# ..        ...     ...        ...         ...       ...        ...         ...
# 886         1       2  22.538659           0         0          0           0
# 887         0       3  22.538659           0         0          0           0
# 888         1       3  22.538659           0         0          0           0
# 889         0       3  22.538659           0         0          0           0
# 890         0       2  22.538659           0         0          0           0
#
# ...

# %%
test
# Out:
#      Pclass      Age_y  title_miss  title_mr  title_mrs  Embarked_Q  \
# 0         3  32.050847           0         1          0           1
# 1         2  32.050847           0         1          0           1
# 2         3  32.050847           0         1          0           0
# 3         3  32.050847           0         1          0           0
# 4         2  32.050847           0         1          0           0
# ..      ...        ...         ...       ...        ...         ...
# 413       3  20.965937           0         0          0           0
# 414       3  20.965937           0         0          0           0
# 415       3  20.965937           0         0          0           0
# 416       1  20.965937           0         0          0           0
# 417       3  20.965937           0         0          0           0
#
#      Embarked_S  family_avg family  family_bade family  Cabin_low  \
# 0             0                  0                   0          1
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dct=DecisionTreeClassifier()
dct.fit(x_train,y_train)
y_pred=dct.predict(x_test)
y_final=dct.predict(test)
accuracy_score(y_pred,y_test)
# Out:
# 0.8156424581005587

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
accuracy_score(y_test,knn.predict(x_test))
# Out:
# 0.8324022346368715

# %%
from sklearn.ensemble import RandomForestClassifier
rf1=RandomForestClassifier(n_estimators=40,max_depth=7,max_samples=0.5,max_features=0.4)
rf1.fit(x_train,y_train)
accuracy_score(y_test,rf1.predict(x_test))
# Out:
# 0.8324022346368715

# %%
from sklearn.ensemble import VotingClassifier
vc= VotingClassifier(estimators=[
    ('knn',knn),('rf1',rf1),('dct',dct),('lr',lr)
])
vc.fit(x_train,y_train)
accuracy_score(y_test,vc.predict(x_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8268156424581006

# %%
from sklearn.preprocessing import StandardScaler
sts = StandardScaler()
x_train_scaled = sts.fit_transform(x_train)
x_test_scaled= sts.transform(x_test)
test_scaled=sts.transform(test)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
accuracy_score(y_test,lr.predict(x_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8100558659217877

# %%
rf=RandomForestClassifier()

# %%
n_estimators=[40,60,80,100,150]
max_feature=[0.4,0.6,0.8,1]
max_depth=[4,5,7,None]
max_sample=[0.5,0.7,1]


param_grid={
    'n_estimators':n_estimators,
    'max_features':max_feature,
    'max_depth':max_depth,
    'max_samples':max_sample
}

# %%
print(param_grid)
# Out:
# {'n_estimators': [40, 60, 80, 100, 150], 'max_features': [0.4, 0.6, 0.8, 1], 'max_depth': [4, 5, 7, None], 'max_sample': [0.5, 0.7, 1]}

# %%
from sklearn.model_selection import GridSearchCV
rf_grid= GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    verbose=2,
    n_jobs=-1

)
rf_grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [4, 5, 7, None],
#                          'max_features': [0.4, 0.6, 0.8, 1],
#                          'max_samples': [0.5, 0.7, 1],
#                          'n_estimators': [40, 60, 80, 100, 150]},
#              verbose=2)

# %%
rf_grid.best_score_
# Out:
# 0.8244952230867723

# %%
y_final000=vc.predict(test)

# %%
final2=pd.DataFrame()
final2['PassengerId']=passengerid
final2['Survived']=y_final000
final2.to_csv('Submission000.csv',index=False)

# %%
tr1
# Out:
#      Survived  Pclass     Sex    Fare Cabin Embarked     title      Age_y  \
# 0           0       3    male  poor p   low        S        mr  32.389610
# 1           0       3    male  poor p   low        S        mr  32.389610
# 2           0       3    male  poor p   low        Q        mr  32.389610
# 3           0       1    male  rich p   low        S        mr  32.389610
# 4           0       3    male  poor p   low        S        mr  32.389610
# ..        ...     ...     ...     ...   ...      ...       ...        ...
# 886         1       2  female  poor p   low        C  bade log  22.538659
# 887         0       3    male  poor p   low        S  bade log  22.538659
# 888         1       3    male  poor p   low        S  bade log  22.538659
# 889         0       3    male  poor p   low        S  bade log  22.538659
# 890         0       2    male  poor p   low        S  bade log  22.538659
#
#          family
# 0    avg family
# 1         alone
# 2         alone
# ...

# %%
tst1
# Out:
#      Pclass     Sex    Fare       Cabin Embarked     title      Age_y  \
# 0         3    male  poor p         low        Q        mr  32.050847
# 1         2    male  poor p         low        Q        mr  32.050847
# 2         3    male  poor p  high class        S        mr  32.050847
# 3         3    male  poor p         low        S        mr  32.050847
# 4         2    male  poor p         low        S        mr  32.050847
# ..      ...     ...     ...         ...      ...       ...        ...
# 413       3    male  poor p         low        S  bade log  20.965937
# 414       3    male  poor p         low        S  bade log  20.965937
# 415       3    male  poor p         low        S  bade log  20.965937
# 416       1  female  rich p         low        C  bade log  20.965937
# 417       3    male  poor p         low        C  bade log  20.965937
#
#           family
# 0          alone
# 1          alone
# 2          alone
# 3          alone
# 4     avg family
# ...
